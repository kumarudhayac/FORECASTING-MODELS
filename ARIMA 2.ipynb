# %%
from datetime import date
from nsepy import get_history
df = get_history(symbol='RELIANCE',
                   start=date(2021,1,1),
                   end=date(2021,12,31))

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
df.index=pd.to_datetime(df.index)

# %%
df
# Out:
#               Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2021-01-01  RELIANCE     EQ     1985.30  1988.00  1997.00  1982.00  1988.00
# 2021-01-04  RELIANCE     EQ     1987.50  1995.10  1998.90  1968.00  1990.25
# 2021-01-05  RELIANCE     EQ     1990.85  1969.00  1983.60  1956.00  1965.00
# 2021-01-06  RELIANCE     EQ     1966.10  1965.90  1966.00  1905.15  1915.50
# 2021-01-07  RELIANCE     EQ     1914.25  1920.50  1945.00  1905.15  1912.80
# ...              ...    ...         ...      ...      ...      ...      ...
# 2021-12-27  RELIANCE     EQ     2372.80  2361.55  2378.00  2348.10  2371.00
# 2021-12-28  RELIANCE     EQ     2370.25  2375.60  2404.85  2373.05  2404.00
# 2021-12-29  RELIANCE     EQ     2398.40  2391.00  2419.00  2382.10  2398.00
# 2021-12-30  RELIANCE     EQ     2402.50  2400.00  2404.95  2345.60  2364.00
# 2021-12-31  RELIANCE     EQ     2359.10  2373.00  2383.90  2360.00  2368.50
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 248 entries, 2021-01-01 to 2021-12-31
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              248 non-null    object
#  1   Series              248 non-null    object
#  2   Prev Close          248 non-null    float64
#  3   Open                248 non-null    float64
#  4   High                248 non-null    float64
#  5   Low                 248 non-null    float64
#  6   Last                248 non-null    float64
#  7   Close               248 non-null    float64
#  8   VWAP                248 non-null    float64
#  9   Volume              248 non-null    int64
#  10  Turnover            248 non-null    float64
#  11  Trades              248 non-null    int64
#  12  Deliverable Volume  248 non-null    int64
#  13  %Deliverble         248 non-null    float64
# dtypes: float64(9), int64(3), object(2)
# ...

# %%
reliance=df.drop(['Symbol','Series','Prev Close','Open','High','Low','Last','VWAP','Volume','Turnover','Trades','Deliverable Volume','%Deliverble' ,'Prev Close' ],axis=1)

# %%
reliance
# Out:
#               Close
# Date
# 2021-01-01  1987.50
# 2021-01-04  1990.85
# 2021-01-05  1966.10
# 2021-01-06  1914.25
# 2021-01-07  1911.15
# ...             ...
# 2021-12-27  2370.25
# 2021-12-28  2398.40
# 2021-12-29  2402.50
# 2021-12-30  2359.10
# 2021-12-31  2368.15
#
# [248 rows x 1 columns]

# %%
reliance.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
reliance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 248 entries, 2021-01-01 to 2021-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   248 non-null    float64
# dtypes: float64(1)
# memory usage: 3.9 KB

# %%
decompose=sm.tsa.seasonal_decompose(reliance,model='additive',period=5)

# %%
fig=decompose.plot()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adf=adfuller(reliance)

# %%
print('adfuller value;',adf[1])
# Out:
# adfuller value; 0.6201398181507849

# %%
reliance1=reliance.diff().dropna()

# %%
adf1=adfuller(reliance1)

# %%
print('adfuller value;',adf1[1])
# Out:
# adfuller value; 5.95341537806586e-18

# %%
reliance1.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
decompose1=sm.tsa.seasonal_decompose(reliance1,model='additive',period=5)

# %%
fig=decompose1.plot()

# %%
len(reliance1)
# Out:
# 247

# %%
train=reliance1[:200]
test=reliance1[200:]

# %%
import itertools

# %%
p=range(0,10)
q=range(0,10)
d=range(0,2)

# %%
pdq_combinations=list(itertools.product(p,d,q))

# %%
len(pdq_combinations)
# Out:
# 200

# %%
rmse=[]
order=[]

# %%
for pdq in pdq_combinations:
    try:
        model=sm.tsa.arima.ARIMA(train,order=pdq).fit()
        predict=model.predict(start=len(train),end=(len(reliance)-2))
        error=np.sqrt(mean_squared_error(test,predict))
        order.append(pdq)
        rmse.append(error)
        
    except:
        continue
# Out:
# C:\Users\udhay\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\udhay\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\udhay\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\udhay\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
# ...

# %%
results=pd.DataFrame(index=order,data=rmse,columns=['RMSE'])

# %%
results.to_csv('arima_results.csv')

# %%
results
# Out:
#                 RMSE
# (0, 0, 0)  45.921840
# (0, 0, 1)  46.017193
# (0, 0, 2)  46.007210
# (0, 0, 3)  45.951058
# (0, 0, 4)  45.969394
# ...              ...
# (9, 1, 5)  45.774003
# (9, 1, 6)  46.522899
# (9, 1, 7)  45.948524
# (9, 1, 8)  46.168503
# (9, 1, 9)  46.953738
#
# [199 rows x 1 columns]

# %%
results.sort_values(by='RMSE')
# Out:
#                 RMSE
# (7, 0, 6)  44.911659
# (9, 0, 5)  45.001276
# (3, 0, 4)  45.068057
# (7, 0, 5)  45.260374
# (6, 0, 5)  45.327392
# ...              ...
# (9, 0, 9)  47.878655
# (4, 1, 0)  49.470241
# (2, 1, 0)  49.556552
# (0, 1, 0)  49.695809
# (3, 1, 0)  50.595004
#
# [199 rows x 1 columns]

# %%
 model=sm.tsa.arima.ARIMA(train,order=(7,0,6)).fit()
# Out:
# C:\Users\udhay\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\udhay\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\udhay\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\udhay\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
# ...

# %%
predict=model.predict(start=len(train),end=(len(reliance1)-1))
# Out:
# C:\Users\udhay\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
test['Close'].plot(legend=True)
predict.plot(legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
 error1=np.sqrt(mean_squared_error(test,predict))

# %%
error
# Out:
# 46.9537382365204

# %%
test['Close'].mean()
# Out:
# -4.9712765957446825

# %%
len(test)
# Out:
# 47

# %%
start=len(train)
end=(len(reliance)-1)

# %%
predict.index=reliance1.index[start:end+1]

# %%
predict
# Out:
# Date
# 2021-10-26     3.714379
# 2021-10-27     1.977929
# 2021-10-28    10.178407
# 2021-10-29   -14.286980
# 2021-11-01     6.757719
# 2021-11-02    -0.445652
# 2021-11-03     9.353322
# 2021-11-04    -4.047336
# 2021-11-08     6.649089
# 2021-11-09    13.243331
# 2021-11-10     1.909191
# 2021-11-11     4.457033
# 2021-11-12    -3.267889
# 2021-11-15    12.428677
# 2021-11-16    -7.265989
# 2021-11-17     0.843316
# 2021-11-18    -1.036888
# 2021-11-22     9.060237
# 2021-11-23     2.870186
# 2021-11-24    -0.145814
# 2021-11-25    11.703437
# 2021-11-26     4.605597
# 2021-11-29     7.133230
# 2021-11-30    -5.942375
# 2021-12-01     8.392559
# 2021-12-02    -0.407323
# 2021-12-03     0.072430
# 2021-12-06    -2.122067
# 2021-12-07     4.990077
# 2021-12-08     8.689971
# 2021-12-09    -0.641951
# 2021-12-10     7.899961
# 2021-12-13     4.241661
# 2021-12-14     9.822335
# 2021-12-15    -3.777865
# 2021-12-16     2.691500
# 2021-12-17     2.255660
# 2021-12-20     1.700578
# ...
